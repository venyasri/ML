# %% [markdown]
# ### Diagnosing the 'Buffering' Issue
#
# To understand why the code might be hanging, we will first check the status of the CSV file and then add print statements to track the execution flow of your data loading cell. This will help us pinpoint where the delay is occurring.

# %% [markdown]
# Now, let's modify your existing data loading cell to include print statements that will show us the progress. This will help determine if the delay is in reading the CSV or displaying its head.

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-3aa3029c-fd42-4655-bd1a-5bf93ead17dd" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-3aa3029c-fd42-4655-bd1a-5bf93ead17dd">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import sys
import pandas as pd
import numpy as np
import sklearn
import matplotlib
import seaborn as sns

from pandas import read_csv

df = read_csv('/content/linear regression dataset.csv')

df.head(6)
df.tail(6)
df.shape
rows, columns = df.shape
rows
df['x']
df.columns
df.dtypes
df.dtypes.value_counts()
df.isnull().sum()

import matplotlib.pyplot as plt
plt.figure(figsize=(10,6))
sns.heatmap(df.isnull(), cbar= False, yticklabels= False, cmap = "viridis")
plt.title("Missing")
plt.show

duplicate_rows = df[df.duplicated()]
print(f"Total no.of Duplicate Rows : {len(duplicate_rows)}")
print(duplicate_rows)
print("-" * 40)

df[df['y'].isnull()]

df.duplicated().sum()

df = df.drop_duplicates()
df.shape

df.describe()

df['x'].value_counts()
(df['x'].value_counts(normalize = True) * 100).round(2)
# Out:
# Total no.of Duplicate Rows : 0
# Empty DataFrame
# Columns: [x, y]
# Index: []
# ----------------------------------------
# x
# 58.000000      2.29
# 49.000000      2.00
# 16.000000      1.86
# 25.000000      1.86
# 24.000000      1.86
#                ...
# 66.000000      0.43
# 69.000000      0.29
# 82.000000      0.29
# 40.000000      0.29
# 3530.157369    0.14
# Name: proportion, Length: 102, dtype: float64
